# %%
import random
random.seed(10)
import os 

initial_path=os.getcwd()
os.chdir(os.getcwd()+'/../..')
from experiments.benchmark_experiment import Experiment

from tsmd.competitors.grammarviz import Grammarviz
from tsmd.competitors.matrixprofile import MatrixProfile
from tsmd.competitors.valmod import Valmod
from tsmd.competitors.mdl import MDL
from tsmd.competitors.locomotif import LocoMotif
from tsmd.competitors.latentmotifs import LatentMotif
from tsmd.competitors.motiflets import Motiflets
from tsmd.competitors.panmatrixprofile import PanMatrixProfile
from tsmd.competitors.persistence import BasePersistentPattern
from tsmd.competitors.setfinder import Baseline
from tsmd.competitors.adaptative_persistence import AdaptativeBasePersistentPattern

os.chdir(initial_path)

# %% [markdown]
# ## Scenario 1: Number of Motifs

# %%
path=initial_path+'/../../data/processed_data/synthetic_data/variable_cardinality/scenario1'
if not os.path.exists(path):
    os.makedirs(path)

# %%
n_motifs_list=[1,2,3,5,10,15,20,50]
generator_params={'motif_length':100, 'motif_amplitude' :4 , 'motif_fundamental':4,
                   'sparsity':0.8,'sparsity_fluctuation':0.5,'length_fluctuation':0,'min_rep':10,'max_rep':10,'noise_amplitude':0.1}

algorithms=[MatrixProfile,PanMatrixProfile,LocoMotif,LatentMotif,MDL,Motiflets,BasePersistentPattern,Valmod,Baseline,AdaptativeBasePersistentPattern]

for n_motifs in n_motifs_list:
    generator_params['n_motifs']=n_motifs
    specific_path=path+'/n_motifs_'+str(n_motifs)+'/'
    if not os.path.exists(specific_path):
        os.makedirs(specific_path)

    exp=Experiment(algorithms)
    exp.run_experiment(specific_path,generator_params)
# Out:
# signal_name: repetition_0, algo: MatrixProfile, , f-auc: 0.78, ami: 0.27
# signal_name: repetition_0, algo: PanMatrixProfile, , f-auc: 0.78, ami: 0.27
# signal_name: repetition_0, algo: LocoMotif, , f-auc: 0.45, ami: -0.0
# signal_name: repetition_0, algo: LatentMotif failed to fit.
# Iteration 1/50 -- [0.0, -inf, -inf]
# Iteration 2/50 -- [358.8174035677547, 0.0, -inf]
# Iteration 3/50 -- [353.0919265369261, 0.0, -97.6059147620125]
# Iteration 4/50 -- [215.44776767525892, 353.0919265369261, 27.660498613610343]
# Iteration 5/50 -- [215.44776767525892, 344.25772544517156, -23.170598458704262]
# Iteration 6/50 -- [215.44776767525892, 338.19298478058056, -37.31980422006836]
# Iteration 7/50 -- [215.44776767525892, 274.4098203934515, -37.31980422006836]
# Iteration 8/50 -- [215.44776767525892, 0.0, -54.0286063080008]
# Iteration 9/50 -- [-inf, 0.0, -18.48387552149191]
# Iteration 10/50 -- [-inf, -inf, -18.48387552149191]
# signal_name: repetition_0, algo: MDL, , f-auc: 0.38, ami: 0.17
# signal_name: repetition_0, algo: Motiflets, , f-auc: 0.61, ami: 0.09
# signal_name: repetition_0, algo: BasePersistentPattern, , f-auc: 0.48, ami: 0.1
# signal_name: repetition_0, algo: Valmod, , f-auc: 0.93, ami: 0.66
# signal_name: repetition_0, algo: Baseline, , f-auc: 0.35, ami: 0.15
# signal_name: repetition_0, algo: AdaptativeBasePersistentPattern, , f-auc: 0.48, ami: 0.11
# signal_name: repetition_1, algo: MatrixProfile, , f-auc: 0.88, ami: 0.48
# signal_name: repetition_1, algo: PanMatrixProfile, , f-auc: 0.88, ami: 0.48
# signal_name: repetition_1, algo: LocoMotif, , f-auc: 0.37, ami: 0.07
# signal_name: repetition_1, algo: LatentMotif, , f-auc: 0.48, ami: 0.09
# Iteration 1/50 -- [0.0, -inf, -inf]
# Iteration 2/50 -- [553.2271034814011, 0.0, -inf]
# Iteration 3/50 -- [179.54312795575996, 552.4722159792375, -206.30637401939225]
# Iteration 4/50 -- [325.35703135415474, 537.573274222892, -215.14057511114675]
# Iteration 5/50 -- [325.35703135415474, 537.0830492272191, -223.19059414228582]
# Iteration 6/50 -- [325.35703135415474, 535.3975581726802, -231.2406131734249]
# Iteration 7/50 -- [325.35703135415474, 533.2976927025704, -241.27575879634514]
# Iteration 8/50 -- [325.35703135415474, 527.7527720753232, -247.31090441926563]

# %%
os.chdir(initial_path+'/../../tsmd')
algorithms=[Grammarviz]

n_motifs_list=[1,2,3,5,10,15,20,50]
generator_params={'motif_length':100, 'motif_amplitude' :4 , 'motif_fundamental':4,
                   'sparsity':0.8,'sparsity_fluctuation':0.5,'length_fluctuation':0,'min_rep':10,'max_rep':10,'noise_amplitude':0.1}
for n_motifs in n_motifs_list:
    generator_params['n_motifs']=n_motifs
    specific_path=path+'/n_motifs_'+str(n_motifs)+'/'
    if not os.path.exists(specific_path):
        os.makedirs(specific_path)

    exp=Experiment(algorithms)
    exp.run_experiment(specific_path,generator_params)
os.chdir(initial_path)

# %% [markdown]
# ## Scenario 2 : Nb of Occurences

# %%
path=initial_path+'/../../data/processed_data/synthetic_data/variable_cardinality/scenario2'
if not os.path.exists(path):
    os.makedirs(path)

# %%
n_occurences_list=[3,5,10,15,20,30,40,50,100]
generator_params={'n_motifs':1,'motif_length':100, 'motif_amplitude' :4 , 'motif_fundamental':4,
                   'sparsity':0.8,'sparsity_fluctuation':0.5,'length_fluctuation':0,'noise_amplitude':0.1}

algorithms=[MatrixProfile,PanMatrixProfile,LocoMotif,LatentMotif,MDL,Motiflets,BasePersistentPattern,Valmod,Baseline,AdaptativeBasePersistentPattern]

for n_occurences in n_occurences_list:
    generator_params['min_rep']=generator_params['max_rep']=n_occurences
    specific_path=path+'/n_occurences_'+str(n_occurences)+'/'
    if not os.path.exists(specific_path):
        os.makedirs(specific_path)

    exp=Experiment(algorithms)
    exp.run_experiment(specific_path,generator_params)
# Out:
# signal_name: repetition_0, algo: MatrixProfile, , f-auc: 0.62, ami: 0.07
# signal_name: repetition_0, algo: PanMatrixProfile, , f-auc: 0.62, ami: 0.07
# signal_name: repetition_0, algo: LocoMotif, , f-auc: 0.0, ami: 0.35
# signal_name: repetition_0, algo: LatentMotif, , f-auc: 0.71, ami: 0.21
# Iteration 1/50 -- [0.0, -inf, -inf]
# Iteration 2/50 -- [249.4556070998145, -200.17635891526277, -inf]
# Iteration 3/50 -- [-inf, -583.4306260003709, -17.435138744116415]
# signal_name: repetition_0, algo: MDL, , f-auc: 0.28, ami: 0.26
# signal_name: repetition_0, algo: Motiflets, , f-auc: 0.58, ami: 0.13
# signal_name: repetition_0, algo: BasePersistentPattern failed to fit.
# signal_name: repetition_0, algo: Valmod, , f-auc: 0.72, ami: 0.22
# signal_name: repetition_0, algo: ValmodWithoutPruning, , f-auc: 0.62, ami: 0.07
# signal_name: repetition_0, algo: Baseline, , f-auc: 0.52, ami: 0.0
# signal_name: repetition_1, algo: MatrixProfile, , f-auc: 0.76, ami: 0.28
# signal_name: repetition_1, algo: PanMatrixProfile, , f-auc: 0.76, ami: 0.28
# signal_name: repetition_1, algo: LocoMotif, , f-auc: 0.0, ami: 0.5
# signal_name: repetition_1, algo: LatentMotif, , f-auc: 0.45, ami: 0.15
# Iteration 1/50 -- [0.0, -inf, -inf]
# Iteration 2/50 -- [415.78209334879284, 0.0, -inf]
# Iteration 3/50 -- [-inf, 0.0, -62.52332455023304]
# Iteration 4/50 -- [-inf, -373.20208777681063, -62.52332455023304]
# signal_name: repetition_1, algo: MDL, , f-auc: 0.51, ami: 0.36
# signal_name: repetition_1, algo: Motiflets, , f-auc: 0.71, ami: 0.32
# signal_name: repetition_1, algo: BasePersistentPattern, , f-auc: 0.48, ami: 0.11
# signal_name: repetition_1, algo: Valmod, , f-auc: 0.89, ami: 0.58
# signal_name: repetition_1, algo: ValmodWithoutPruning, , f-auc: 0.76, ami: 0.28
# signal_name: repetition_1, algo: Baseline, , f-auc: 0.42, ami: 0.02
# signal_name: repetition_2, algo: MatrixProfile, , f-auc: 0.86, ami: 0.52
# signal_name: repetition_2, algo: PanMatrixProfile, , f-auc: 0.86, ami: 0.52
# signal_name: repetition_2, algo: LocoMotif, , f-auc: 0.0, ami: 0.38
# signal_name: repetition_2, algo: LatentMotif, , f-auc: 0.54, ami: 0.03
# Iteration 1/50 -- [0.0, -inf, -inf]
# Iteration 2/50 -- [518.2724850390177, -215.48072995211564, -inf]
# Iteration 3/50 -- [-inf, 513.331508401026, -214.66477730634142]
# Iteration 4/50 -- [-inf, -inf, -222.7295179709323]
# signal_name: repetition_2, algo: MDL, , f-auc: 1.0, ami: 0.78
# signal_name: repetition_2, algo: Motiflets, , f-auc: 0.8, ami: 0.5
# signal_name: repetition_2, algo: BasePersistentPattern, , f-auc: 0.58, ami: 0.17
# signal_name: repetition_2, algo: Valmod, , f-auc: 1.0, ami: 1.0
# signal_name: repetition_2, algo: ValmodWithoutPruning, , f-auc: 0.86, ami: 0.52
# signal_name: repetition_2, algo: Baseline, , f-auc: 0.43, ami: 0.01
# signal_name: repetition_3, algo: MatrixProfile, , f-auc: 0.69, ami: 0.15
# signal_name: repetition_3, algo: PanMatrixProfile, , f-auc: 0.69, ami: 0.15
# signal_name: repetition_3, algo: LocoMotif, , f-auc: 0.0, ami: 0.47
# signal_name: repetition_3, algo: LatentMotif, , f-auc: 0.4, ami: 0.09
# Iteration 1/50 -- [0.0, -inf, -inf]
# Iteration 2/50 -- [504.7832619152098, 0.0, -inf]
# Iteration 3/50 -- [-337.42444545557896, 0.0, -136.31911173296874]
# Iteration 4/50 -- [-inf, -360.9260992960608, -136.31911173296874]
# signal_name: repetition_3, algo: MDL, , f-auc: 0.71, ami: 0.42
# signal_name: repetition_3, algo: Motiflets, , f-auc: 0.64, ami: 0.2
# signal_name: repetition_3, algo: BasePersistentPattern, , f-auc: 0.48, ami: 0.1
# signal_name: repetition_3, algo: Valmod, , f-auc: 0.8, ami: 0.36
# signal_name: repetition_3, algo: ValmodWithoutPruning, , f-auc: 0.69, ami: 0.15
# signal_name: repetition_3, algo: Baseline, , f-auc: 0.35, ami: 0.11
# signal_name: repetition_4, algo: MatrixProfile, , f-auc: 0.84, ami: 0.5
# signal_name: repetition_4, algo: PanMatrixProfile, , f-auc: 0.84, ami: 0.5
# signal_name: repetition_4, algo: LocoMotif, , f-auc: 0.0, ami: 0.37
# signal_name: repetition_4, algo: LatentMotif, , f-auc: 0.31, ami: 0.0
# Iteration 1/50 -- [0.0, -inf, -inf]
# Iteration 2/50 -- [364.0535005742822, 0.0, -inf]
# Iteration 3/50 -- [-inf, 0.0, -46.79115674194236]
# Iteration 4/50 -- [-inf, -549.5577762779358, -46.79115674194236]
# signal_name: repetition_4, algo: MDL, , f-auc: 0.44, ami: 0.4
# signal_name: repetition_4, algo: Motiflets, , f-auc: 0.78, ami: 0.48
# signal_name: repetition_4, algo: BasePersistentPattern, , f-auc: 0.58, ami: 0.23
# signal_name: repetition_4, algo: Valmod, , f-auc: 0.98, ami: 0.93
# signal_name: repetition_4, algo: ValmodWithoutPruning, , f-auc: 0.84, ami: 0.5
# signal_name: repetition_4, algo: Baseline, , f-auc: 0.42, ami: 0.02
# signal_name: repetition_5, algo: MatrixProfile, , f-auc: 0.78, ami: 0.31
# signal_name: repetition_5, algo: PanMatrixProfile, , f-auc: 0.78, ami: 0.31
# signal_name: repetition_5, algo: LocoMotif, , f-auc: 0.0, ami: 0.35
# signal_name: repetition_5, algo: LatentMotif, , f-auc: 0.3, ami: 0.03
# Iteration 1/50 -- [0.0, -inf, -inf]
# Iteration 2/50 -- [141.0663545987896, -171.1697446642854, -inf]
# Iteration 3/50 -- [-inf, -631.2492170349417, -4.699906248435212]
# signal_name: repetition_5, algo: MDL, , f-auc: 0.17, ami: 0.38
# signal_name: repetition_5, algo: Motiflets, , f-auc: 0.73, ami: 0.34
# signal_name: repetition_5, algo: BasePersistentPattern failed to fit.
# signal_name: repetition_5, algo: Valmod, , f-auc: 0.91, ami: 0.64
# signal_name: repetition_5, algo: ValmodWithoutPruning, , f-auc: 0.78, ami: 0.31
# signal_name: repetition_5, algo: Baseline, , f-auc: 0.41, ami: 0.05
# signal_name: repetition_6, algo: MatrixProfile, , f-auc: 0.86, ami: 0.55
# signal_name: repetition_6, algo: PanMatrixProfile, , f-auc: 0.86, ami: 0.55
# signal_name: repetition_6, algo: LocoMotif, , f-auc: 0.0, ami: 0.47
# signal_name: repetition_6, algo: LatentMotif, , f-auc: 0.82, ami: 0.41
# Iteration 1/50 -- [512.7627100346909, -inf, -inf]
# Iteration 2/50 -- [1.9599444607389458, 504.6833964450999, -inf]
# Iteration 3/50 -- [37.26049032509931, -1022.2523008881648, -inf]
# Iteration 4/50 -- [-inf, -104.72293499301745, -139.07785066728286]
# signal_name: repetition_6, algo: MDL, , f-auc: 0.92, ami: 0.52
# signal_name: repetition_6, algo: Motiflets, , f-auc: 0.8, ami: 0.52
# signal_name: repetition_6, algo: BasePersistentPattern, , f-auc: 0.48, ami: 0.15
# signal_name: repetition_6, algo: Valmod, , f-auc: 1.0, ami: 1.0
# signal_name: repetition_6, algo: ValmodWithoutPruning, , f-auc: 0.86, ami: 0.55
# signal_name: repetition_6, algo: Baseline, , f-auc: 0.32, ami: 0.07
# signal_name: repetition_7, algo: MatrixProfile, , f-auc: 0.84, ami: 0.48
# signal_name: repetition_7, algo: PanMatrixProfile, , f-auc: 0.84, ami: 0.48
# signal_name: repetition_7, algo: LocoMotif, , f-auc: 0.0, ami: 0.39
# signal_name: repetition_7, algo: LatentMotif, , f-auc: 0.23, ami: -0.0
# Iteration 1/50 -- [0.0, -inf, -inf]
# Iteration 2/50 -- [338.318506507809, -230.53385189893993, -inf]
# Iteration 3/50 -- [-inf, -486.3608877147965, -38.32694639141948]
# signal_name: repetition_7, algo: MDL, , f-auc: 0.4, ami: 0.26
# signal_name: repetition_7, algo: Motiflets, , f-auc: 0.78, ami: 0.47
# signal_name: repetition_7, algo: BasePersistentPattern, , f-auc: 0.52, ami: 0.15
# signal_name: repetition_7, algo: Valmod, , f-auc: 0.98, ami: 0.93
# signal_name: repetition_7, algo: ValmodWithoutPruning, , f-auc: 0.84, ami: 0.48
# signal_name: repetition_7, algo: Baseline, , f-auc: 0.32, ami: 0.08
# signal_name: repetition_8, algo: MatrixProfile, , f-auc: 0.86, ami: 0.55
# signal_name: repetition_8, algo: PanMatrixProfile, , f-auc: 0.86, ami: 0.55
# signal_name: repetition_8, algo: LocoMotif, , f-auc: 0.0, ami: 0.42
# signal_name: repetition_8, algo: LatentMotif, , f-auc: 0.38, ami: 0.08
# Iteration 1/50 -- [0.0, -inf, -inf]
# Iteration 2/50 -- [127.43095546405661, 0.0, -inf]
# Iteration 3/50 -- [-inf, -599.8364298411901, -3.922356969270453]
# signal_name: repetition_8, algo: MDL, , f-auc: 0.13, ami: 0.35
# signal_name: repetition_8, algo: Motiflets, , f-auc: 0.8, ami: 0.52
# signal_name: repetition_8, algo: BasePersistentPattern, , f-auc: 0.46, ami: 0.09
# signal_name: repetition_8, algo: Valmod, , f-auc: 1.0, ami: 1.0
# signal_name: repetition_8, algo: ValmodWithoutPruning, , f-auc: 0.86, ami: 0.55
# signal_name: repetition_8, algo: Baseline, , f-auc: 0.66, ami: 0.14
# signal_name: repetition_9, algo: MatrixProfile, , f-auc: 0.86, ami: 0.43
# signal_name: repetition_9, algo: PanMatrixProfile, , f-auc: 0.86, ami: 0.43
# signal_name: repetition_9, algo: LocoMotif, , f-auc: 0.0, ami: 0.3
# signal_name: repetition_9, algo: LatentMotif, , f-auc: 0.74, ami: 0.24
# Iteration 1/50 -- [0.0, -inf, -inf]
# Iteration 2/50 -- [340.60372089481814, -80.49867237206485, -inf]
# Iteration 3/50 -- [-inf, -439.5248367916121, -38.32694639141948]
# signal_name: repetition_9, algo: MDL, , f-auc: 0.4, ami: 0.24
# signal_name: repetition_9, algo: Motiflets, , f-auc: 0.76, ami: 0.41
# signal_name: repetition_9, algo: BasePersistentPattern, , f-auc: 0.49, ami: 0.11
# signal_name: repetition_9, algo: Valmod, , f-auc: 0.95, ami: 0.78
# signal_name: repetition_9, algo: ValmodWithoutPruning, , f-auc: 0.81, ami: 0.4
# signal_name: repetition_9, algo: Baseline, , f-auc: 0.36, ami: 0.05
# signal_name: repetition_10, algo: MatrixProfile, , f-auc: 0.69, ami: 0.16
# signal_name: repetition_10, algo: PanMatrixProfile, , f-auc: 0.69, ami: 0.16
# signal_name: repetition_10, algo: LocoMotif, , f-auc: 0.0, ami: 0.35
# signal_name: repetition_10, algo: LatentMotif, , f-auc: 0.7, ami: 0.31
# Iteration 1/50 -- [0.0, -inf, -inf]
# Iteration 2/50 -- [241.5514178857178, 0.0, -inf]
# Iteration 3/50 -- [-inf, 0.0, -20.00337117682227]
# Iteration 4/50 -- [-inf, -458.25213734934147, -20.00337117682227]
# signal_name: repetition_10, algo: MDL, , f-auc: 0.3, ami: 0.44
# signal_name: repetition_10, algo: Motiflets, , f-auc: 0.64, ami: 0.21
# signal_name: repetition_10, algo: BasePersistentPattern, , f-auc: 0.54, ami: 0.2
# signal_name: repetition_10, algo: Valmod, , f-auc: 0.8, ami: 0.37
# signal_name: repetition_10, algo: ValmodWithoutPruning, , f-auc: 0.69, ami: 0.16
# signal_name: repetition_10, algo: Baseline, , f-auc: 0.52, ami: 0.0
# signal_name: repetition_11, algo: MatrixProfile, , f-auc: 0.84, ami: 0.52
# signal_name: repetition_11, algo: PanMatrixProfile, , f-auc: 0.84, ami: 0.52
# signal_name: repetition_11, algo: LocoMotif, , f-auc: 0.0, ami: 0.47
# signal_name: repetition_11, algo: LatentMotif, , f-auc: 0.25, ami: 0.0
# Iteration 1/50 -- [0.0, -inf, -inf]
# Iteration 2/50 -- [471.5277753148039, 0.0, -inf]
# Iteration 3/50 -- [-28.24933618603243, 0.0, -102.48442789473643]
# Iteration 4/50 -- [-inf, -363.65302984795426, -102.48442789473643]
# signal_name: repetition_11, algo: MDL, , f-auc: 0.64, ami: 0.33
# signal_name: repetition_11, algo: Motiflets, , f-auc: 0.78, ami: 0.49
# signal_name: repetition_11, algo: BasePersistentPattern, , f-auc: 0.46, ami: 0.13
# signal_name: repetition_11, algo: Valmod, , f-auc: 0.98, ami: 0.93
# signal_name: repetition_11, algo: ValmodWithoutPruning, , f-auc: 0.84, ami: 0.52
# signal_name: repetition_11, algo: Baseline, , f-auc: 0.16, ami: 0.38
# signal_name: repetition_12, algo: MatrixProfile, , f-auc: 0.84, ami: 0.51
# signal_name: repetition_12, algo: PanMatrixProfile, , f-auc: 0.84, ami: 0.51
# signal_name: repetition_12, algo: LocoMotif, , f-auc: 0.0, ami: 0.42
# signal_name: repetition_12, algo: LatentMotif, , f-auc: 0.02, ami: 0.1
# Iteration 1/50 -- [0.0, -inf, -inf]
# Iteration 2/50 -- [159.18511717297363, 0.0, -inf]
# Iteration 3/50 -- [-inf, -556.1513781469229, -9.11319941500696]
# signal_name: repetition_12, algo: MDL, , f-auc: 0.2, ami: 0.27
# signal_name: repetition_12, algo: Motiflets, , f-auc: 0.78, ami: 0.49
# signal_name: repetition_12, algo: BasePersistentPattern, , f-auc: 0.45, ami: 0.09
# signal_name: repetition_12, algo: Valmod, , f-auc: 0.98, ami: 0.93
# signal_name: repetition_12, algo: ValmodWithoutPruning, , f-auc: 0.84, ami: 0.51
# signal_name: repetition_12, algo: Baseline, , f-auc: 0.13, ami: 0.39
# signal_name: repetition_13, algo: MatrixProfile, , f-auc: 0.84, ami: 0.52
# signal_name: repetition_13, algo: PanMatrixProfile, , f-auc: 0.84, ami: 0.52
# signal_name: repetition_13, algo: LocoMotif, , f-auc: 0.0, ami: 0.32
# signal_name: repetition_13, algo: LatentMotif, , f-auc: 0.0, ami: 0.13
# Iteration 1/50 -- [0.0, -inf, -inf]
# Iteration 2/50 -- [259.45560709981453, 0.0, -inf]
# Iteration 3/50 -- [-inf, 0.0, -17.014725444054477]
# Iteration 4/50 -- [-inf, -534.880284363775, -17.014725444054477]
# signal_name: repetition_13, algo: MDL, , f-auc: 0.27, ami: 0.38
# signal_name: repetition_13, algo: Motiflets, , f-auc: 0.78, ami: 0.5
# signal_name: repetition_13, algo: BasePersistentPattern, , f-auc: 0.46, ami: 0.12
# signal_name: repetition_13, algo: Valmod, , f-auc: 0.98, ami: 0.93
# signal_name: repetition_13, algo: ValmodWithoutPruning, , f-auc: 0.84, ami: 0.52
# signal_name: repetition_13, algo: Baseline, , f-auc: 0.6, ami: 0.09
# signal_name: repetition_14, algo: MatrixProfile, , f-auc: 0.86, ami: 0.56
# signal_name: repetition_14, algo: PanMatrixProfile, , f-auc: 0.86, ami: 0.56
# signal_name: repetition_14, algo: LocoMotif, , f-auc: 0.0, ami: 0.34
# signal_name: repetition_14, algo: LatentMotif, , f-auc: 0.3, ami: 0.01
# Iteration 1/50 -- [0.0, -inf, -inf]
# Iteration 2/50 -- [0.0, 0.0, -inf]
# Iteration 3/50 -- [548.3929023896465, -209.12771633401056, 0.0]
# Iteration 4/50 -- [-inf, 533.7879176982435, 0.0]
# Iteration 5/50 -- [-inf, -inf, 0.0]
# Iteration 6/50 -- [-inf, -inf, -227.8873237776603]
# signal_name: repetition_14, algo: MDL, , f-auc: 1.0, ami: 0.81
# signal_name: repetition_14, algo: Motiflets, , f-auc: 0.8, ami: 0.53
# signal_name: repetition_14, algo: BasePersistentPattern, , f-auc: 0.47, ami: 0.15
# signal_name: repetition_14, algo: Valmod, , f-auc: 1.0, ami: 1.0
# signal_name: repetition_14, algo: ValmodWithoutPruning, , f-auc: 0.86, ami: 0.56
# signal_name: repetition_14, algo: Baseline, , f-auc: 0.27, ami: 0.13
# signal_name: repetition_15, algo: MatrixProfile, , f-auc: 0.41, ami: 0.0
# signal_name: repetition_15, algo: PanMatrixProfile, , f-auc: 0.41, ami: 0.0
# signal_name: repetition_15, algo: LocoMotif, , f-auc: 0.0, ami: 0.38
# signal_name: repetition_15, algo: LatentMotif, , f-auc: 0.74, ami: 0.27
# Iteration 1/50 -- [0.0, -inf, -inf]
# Iteration 2/50 -- [0.0, 0.0, -inf]
# Iteration 3/50 -- [516.5928242315462, -282.91855843623176, 0.0]
# Iteration 4/50 -- [-inf, 519.6880522281335, 0.0]
# Iteration 5/50 -- [-inf, -inf, 0.0]
# Iteration 6/50 -- [-inf, -inf, -232.73551476953298]
# signal_name: repetition_15, algo: MDL, , f-auc: 1.0, ami: 0.83
# signal_name: repetition_15, algo: Motiflets, , f-auc: 0.38, ami: 0.01
# signal_name: repetition_15, algo: BasePersistentPattern, , f-auc: 0.49, ami: 0.15
# signal_name: repetition_15, algo: Valmod, , f-auc: 0.48, ami: 0.02
# signal_name: repetition_15, algo: ValmodWithoutPruning, , f-auc: 0.41, ami: 0.0
# signal_name: repetition_15, algo: Baseline, , f-auc: 0.46, ami: 0.01
# signal_name: repetition_16, algo: MatrixProfile, , f-auc: 0.7, ami: 0.18
# signal_name: repetition_16, algo: PanMatrixProfile, , f-auc: 0.7, ami: 0.18
# signal_name: repetition_16, algo: LocoMotif, , f-auc: 0.0, ami: 0.33
# signal_name: repetition_16, algo: LatentMotif, , f-auc: 0.19, ami: 0.0
# Iteration 1/50 -- [0.0, -inf, -inf]
# Iteration 2/50 -- [374.62303915954635, 0.0, -inf]
# Iteration 3/50 -- [-210.18083599666943, 0.0, -46.161434197397455]
# Iteration 4/50 -- [-inf, -487.16177063433804, -46.161434197397455]
# signal_name: repetition_16, algo: MDL, , f-auc: 0.44, ami: 0.31
# signal_name: repetition_16, algo: Motiflets, , f-auc: 0.65, ami: 0.22
# signal_name: repetition_16, algo: BasePersistentPattern, , f-auc: 0.48, ami: 0.16
# signal_name: repetition_16, algo: Valmod, , f-auc: 0.81, ami: 0.4
# signal_name: repetition_16, algo: ValmodWithoutPruning, , f-auc: 0.7, ami: 0.18
# signal_name: repetition_16, algo: Baseline, , f-auc: 0.68, ami: 0.18
# signal_name: repetition_17, algo: MatrixProfile, , f-auc: 0.73, ami: 0.21
# signal_name: repetition_17, algo: PanMatrixProfile, , f-auc: 0.73, ami: 0.21
# signal_name: repetition_17, algo: LocoMotif, , f-auc: 0.0, ami: 0.54
# signal_name: repetition_17, algo: LatentMotif, , f-auc: 0.47, ami: 0.01
# Iteration 1/50 -- [0.0, -inf, -inf]
# Iteration 2/50 -- [289.1560006679187, -40.413142464428674, -inf]
# Iteration 3/50 -- [-inf, -478.14446870973745, -28.588545000990734]
# signal_name: repetition_17, algo: MDL, , f-auc: 0.36, ami: 0.23
# signal_name: repetition_17, algo: Motiflets, , f-auc: 0.68, ami: 0.26
# signal_name: repetition_17, algo: BasePersistentPattern, , f-auc: 0.3, ami: 0.14
# signal_name: repetition_17, algo: Valmod, , f-auc: 0.85, ami: 0.47
# signal_name: repetition_17, algo: ValmodWithoutPruning, , f-auc: 0.73, ami: 0.21
# signal_name: repetition_17, algo: Baseline, , f-auc: 0.49, ami: 0.0
# signal_name: repetition_18, algo: MatrixProfile, , f-auc: 0.84, ami: 0.48
# signal_name: repetition_18, algo: PanMatrixProfile, , f-auc: 0.84, ami: 0.48
# signal_name: repetition_18, algo: LocoMotif, , f-auc: 0.0, ami: 0.42
# signal_name: repetition_18, algo: LatentMotif, , f-auc: 0.03, ami: 0.24
# Iteration 1/50 -- [0.0, -inf, -inf]
# Iteration 2/50 -- [497.41773206674463, -80.49867237206485, -inf]
# Iteration 3/50 -- [-inf, -209.26158091090383, -106.20088128214331]
# signal_name: repetition_18, algo: MDL, , f-auc: 0.63, ami: 0.28
# signal_name: repetition_18, algo: Motiflets, , f-auc: 0.78, ami: 0.47
# signal_name: repetition_18, algo: BasePersistentPattern, , f-auc: 0.53, ami: 0.1
# signal_name: repetition_18, algo: Valmod, , f-auc: 0.98, ami: 0.93
# signal_name: repetition_18, algo: ValmodWithoutPruning, , f-auc: 0.84, ami: 0.48
# signal_name: repetition_18, algo: Baseline, , f-auc: 0.43, ami: 0.0
# signal_name: repetition_19, algo: MatrixProfile, , f-auc: 0.76, ami: 0.31
# signal_name: repetition_19, algo: PanMatrixProfile, , f-auc: 0.76, ami: 0.31
# signal_name: repetition_19, algo: LocoMotif, , f-auc: 0.0, ami: 0.37
# signal_name: repetition_19, algo: LatentMotif, , f-auc: 0.16, ami: 0.0
# Iteration 1/50 -- [542.146788019945, -inf, -inf]
# Iteration 2/50 -- [113.91785044470633, 524.0107362247674, -inf]
# Iteration 3/50 -- [-inf, -1055.2067141141679, -inf]
# signal_name: repetition_19, algo: MDL, , f-auc: 0.9, ami: 0.63
# signal_name: repetition_19, algo: Motiflets, , f-auc: 0.71, ami: 0.33
# signal_name: repetition_19, algo: BasePersistentPattern, , f-auc: 0.3, ami: 0.12
# signal_name: repetition_19, algo: Valmod, , f-auc: 0.89, ami: 0.6
# signal_name: repetition_19, algo: ValmodWithoutPruning, , f-auc: 0.76, ami: 0.31
# signal_name: repetition_19, algo: Baseline, , f-auc: 0.21, ami: 0.21
# signal_name: repetition_20, algo: MatrixProfile, , f-auc: 0.79, ami: 0.34
# signal_name: repetition_20, algo: PanMatrixProfile, , f-auc: 0.79, ami: 0.34
# signal_name: repetition_20, algo: LocoMotif, , f-auc: 0.0, ami: 0.43
# signal_name: repetition_20, algo: LatentMotif, , f-auc: 0.06, ami: 0.26
# Iteration 1/50 -- [0.0, -inf, -inf]
# Iteration 2/50 -- [331.1732594800823, 0.0, -inf]
# Iteration 3/50 -- [-inf, -449.04025440478995, -37.744375108173415]
# signal_name: repetition_20, algo: MDL, , f-auc: 0.4, ami: 0.21
# signal_name: repetition_20, algo: Motiflets, , f-auc: 0.74, ami: 0.36
# signal_name: repetition_20, algo: BasePersistentPattern failed to fit.
# signal_name: repetition_20, algo: Valmod, , f-auc: 0.92, ami: 0.68
# signal_name: repetition_20, algo: ValmodWithoutPruning, , f-auc: 0.79, ami: 0.34
# signal_name: repetition_20, algo: Baseline, , f-auc: 0.35, ami: 0.02
# signal_name: repetition_21, algo: MatrixProfile, , f-auc: 0.81, ami: 0.42
# signal_name: repetition_21, algo: PanMatrixProfile, , f-auc: 0.81, ami: 0.42
# signal_name: repetition_21, algo: LocoMotif, , f-auc: 0.0, ami: 0.35
# signal_name: repetition_21, algo: LatentMotif, , f-auc: 0.39, ami: -0.0
# Iteration 1/50 -- [0.0, -inf, -inf]
# Iteration 2/50 -- [189.22421719028137, -149.488049760557, -inf]
# Iteration 3/50 -- [-inf, -548.21900181019, -9.11319941500696]
# signal_name: repetition_21, algo: MDL, , f-auc: 0.2, ami: 0.29
# signal_name: repetition_21, algo: Motiflets, , f-auc: 0.76, ami: 0.42
# signal_name: repetition_21, algo: BasePersistentPattern, , f-auc: 0.5, ami: 0.15
# signal_name: repetition_21, algo: Valmod, , f-auc: 0.95, ami: 0.79
# signal_name: repetition_21, algo: ValmodWithoutPruning, , f-auc: 0.81, ami: 0.42
# signal_name: repetition_21, algo: Baseline, , f-auc: 0.44, ami: 0.0
# signal_name: repetition_22, algo: MatrixProfile, , f-auc: 0.79, ami: 0.32
# signal_name: repetition_22, algo: PanMatrixProfile, , f-auc: 0.79, ami: 0.32
# signal_name: repetition_22, algo: LocoMotif, , f-auc: 0.0, ami: 0.61
# signal_name: repetition_22, algo: LatentMotif, , f-auc: 0.97, ami: 0.87
# Iteration 1/50 -- [0.0, -inf, -inf]
# Iteration 2/50 -- [545.3269689515108, -36.12348406415177, -inf]
# Iteration 3/50 -- [-inf, 533.7378803575928, -222.74409089593246]
# Iteration 4/50 -- [-inf, -inf, -230.80883156052346]
# signal_name: repetition_22, algo: MDL, , f-auc: 1.0, ami: 0.78
# signal_name: repetition_22, algo: Motiflets, , f-auc: 0.74, ami: 0.35
# signal_name: repetition_22, algo: BasePersistentPattern, , f-auc: 0.54, ami: 0.11
# signal_name: repetition_22, algo: Valmod, , f-auc: 0.92, ami: 0.67
# signal_name: repetition_22, algo: ValmodWithoutPruning, , f-auc: 0.92, ami: 0.67
# signal_name: repetition_22, algo: Baseline, , f-auc: 0.45, ami: 0.05
# signal_name: repetition_23, algo: MatrixProfile, , f-auc: 0.57, ami: 0.04
# signal_name: repetition_23, algo: PanMatrixProfile, , f-auc: 0.57, ami: 0.04
# signal_name: repetition_23, algo: LocoMotif, , f-auc: 0.0, ami: 0.33
# signal_name: repetition_23, algo: LatentMotif, , f-auc: 0.23, ami: 0.0
# Iteration 1/50 -- [0.0, -inf, -inf]
# Iteration 2/50 -- [529.0881379939833, -84.56610991291501, -inf]
# Iteration 3/50 -- [-inf, 521.3964399672968, -158.0793622424909]
# Iteration 4/50 -- [-inf, -inf, -170.46278246922213]
# signal_name: repetition_23, algo: MDL, , f-auc: 1.0, ami: 0.77
# signal_name: repetition_23, algo: Motiflets, , f-auc: 0.53, ami: 0.08
# signal_name: repetition_23, algo: BasePersistentPattern, , f-auc: 0.52, ami: 0.15
# signal_name: repetition_23, algo: Valmod, , f-auc: 0.66, ami: 0.14
# signal_name: repetition_23, algo: ValmodWithoutPruning, , f-auc: 0.57, ami: 0.04
# signal_name: repetition_23, algo: Baseline, , f-auc: 0.42, ami: 0.01
# signal_name: repetition_24, algo: MatrixProfile, , f-auc: 0.68, ami: 0.16
# signal_name: repetition_24, algo: PanMatrixProfile, , f-auc: 0.68, ami: 0.16
# signal_name: repetition_24, algo: LocoMotif, , f-auc: 0.0, ami: 0.55
# signal_name: repetition_24, algo: LatentMotif, , f-auc: 0.17, ami: 0.03
# Iteration 1/50 -- [0.0, -inf, -inf]
# Iteration 2/50 -- [526.3929023896463, 0.0, -inf]
# Iteration 3/50 -- [-241.0922553098622, 0.0, -162.07420745009733]
# Iteration 4/50 -- [-inf, -212.41955827335732, -162.07420745009733]
# signal_name: repetition_24, algo: MDL, , f-auc: 0.75, ami: 0.47
# signal_name: repetition_24, algo: Motiflets, , f-auc: 0.58, ami: 0.12
# signal_name: repetition_24, algo: BasePersistentPattern, , f-auc: 0.51, ami: 0.12
# signal_name: repetition_24, algo: Valmod, , f-auc: 0.72, ami: 0.22
# signal_name: repetition_24, algo: ValmodWithoutPruning, , f-auc: 0.68, ami: 0.16
# signal_name: repetition_24, algo: Baseline, , f-auc: 0.33, ami: 0.08
# signal_name: repetition_25, algo: MatrixProfile, , f-auc: 0.79, ami: 0.32
# signal_name: repetition_25, algo: PanMatrixProfile, , f-auc: 0.79, ami: 0.32
# signal_name: repetition_25, algo: LocoMotif, , f-auc: 0.0, ami: 0.45
# signal_name: repetition_25, algo: LatentMotif, , f-auc: 0.52, ami: 0.02
# Iteration 1/50 -- [0.0, -inf, -inf]
# Iteration 2/50 -- [355.181931544355, -28.28810850836414, -inf]
# Iteration 3/50 -- [-inf, -368.4583420739338, -53.00368658708413]
# signal_name: repetition_25, algo: MDL, , f-auc: 0.49, ami: 0.24
# signal_name: repetition_25, algo: Motiflets, , f-auc: 0.74, ami: 0.35
# signal_name: repetition_25, algo: BasePersistentPattern, , f-auc: 0.49, ami: 0.08
# signal_name: repetition_25, algo: Valmod, , f-auc: 0.92, ami: 0.67
# signal_name: repetition_25, algo: ValmodWithoutPruning, , f-auc: 0.79, ami: 0.32
# signal_name: repetition_25, algo: Baseline, , f-auc: 0.41, ami: -0.0
# signal_name: repetition_26, algo: MatrixProfile, , f-auc: 0.48, ami: 0.03
# signal_name: repetition_26, algo: PanMatrixProfile, , f-auc: 0.48, ami: 0.03
# signal_name: repetition_26, algo: LocoMotif, , f-auc: 0.0, ami: 0.39
# signal_name: repetition_26, algo: LatentMotif, , f-auc: 0.31, ami: 0.0
# Iteration 1/50 -- [0.0, -inf, -inf]
# Iteration 2/50 -- [282.61064138613636, -170.66614865443003, -inf]
# Iteration 3/50 -- [-inf, -562.8676232324909, -22.53654874495868]
# signal_name: repetition_26, algo: MDL, , f-auc: 0.31, ami: 0.32
# signal_name: repetition_26, algo: Motiflets, , f-auc: 0.45, ami: 0.02
# signal_name: repetition_26, algo: BasePersistentPattern, , f-auc: 0.54, ami: 0.16
# signal_name: repetition_26, algo: Valmod, , f-auc: 0.56, ami: 0.04
# signal_name: repetition_26, algo: ValmodWithoutPruning, , f-auc: 0.56, ami: 0.04
# signal_name: repetition_26, algo: Baseline, , f-auc: 0.74, ami: 0.25
# signal_name: repetition_27, algo: MatrixProfile, , f-auc: 0.86, ami: 0.56
# signal_name: repetition_27, algo: PanMatrixProfile, , f-auc: 0.86, ami: 0.56
# signal_name: repetition_27, algo: LocoMotif, , f-auc: 0.0, ami: 0.24
# signal_name: repetition_27, algo: LatentMotif, , f-auc: 0.19, ami: 0.02
# Iteration 1/50 -- [0.0, -inf, -inf]
# Iteration 2/50 -- [121.4309554640566, 0.0, -inf]
# Iteration 3/50 -- [-inf, 0.0, -3.7092209932693265]
# Iteration 4/50 -- [-inf, -667.5604184942658, -3.7092209932693265]
# signal_name: repetition_27, algo: MDL, , f-auc: 0.13, ami: 0.55
# signal_name: repetition_27, algo: Motiflets, , f-auc: 0.8, ami: 0.53
# signal_name: repetition_27, algo: BasePersistentPattern failed to fit.
# signal_name: repetition_27, algo: Valmod, , f-auc: 1.0, ami: 1.0
# signal_name: repetition_27, algo: ValmodWithoutPruning, , f-auc: 0.86, ami: 0.56
# signal_name: repetition_27, algo: Baseline, , f-auc: 0.25, ami: 0.19
# signal_name: repetition_28, algo: MatrixProfile, , f-auc: 0.83, ami: 0.46
# signal_name: repetition_28, algo: PanMatrixProfile, , f-auc: 0.83, ami: 0.46
# signal_name: repetition_28, algo: LocoMotif, , f-auc: 0.0, ami: 0.36
# signal_name: repetition_28, algo: LatentMotif, , f-auc: 0.23, ami: 0.0
# Iteration 1/50 -- [0.0, -inf, -inf]
# Iteration 2/50 -- [498.29831658798065, -144.905082157795, -inf]
# Iteration 3/50 -- [-inf, 484.8833182869992, -200.95323639839438]
# Iteration 4/50 -- [-inf, -inf, -207.85800840180679]
# signal_name: repetition_28, algo: MDL, , f-auc: 1.0, ami: 0.77
# signal_name: repetition_28, algo: Motiflets, , f-auc: 0.78, ami: 0.46
# signal_name: repetition_28, algo: BasePersistentPattern, , f-auc: 0.34, ami: 0.13
# signal_name: repetition_28, algo: Valmod, , f-auc: 0.97, ami: 0.87
# signal_name: repetition_28, algo: ValmodWithoutPruning, , f-auc: 0.83, ami: 0.46
# signal_name: repetition_28, algo: Baseline, , f-auc: 0.3, ami: 0.11
# signal_name: repetition_29, algo: MatrixProfile, , f-auc: 0.86, ami: 0.57
# signal_name: repetition_29, algo: PanMatrixProfile, , f-auc: 0.86, ami: 0.57
# signal_name: repetition_29, algo: LocoMotif, , f-auc: 0.0, ami: 0.52
# signal_name: repetition_29, algo: LatentMotif, , f-auc: 0.2, ami: 0.05
# Iteration 1/50 -- [0.0, -inf, -inf]
# Iteration 2/50 -- [60.21791902022727, 0.0, -inf]
# Iteration 3/50 -- [518.4184681742274, 0.0, -0.924312235954865]
# Iteration 4/50 -- [-inf, 0.0, -0.924312235954865]

# %%
n_occurences_list=[3,5,10,15,20,30,40,50,100]
generator_params={'n_motifs':1,'motif_length':100, 'motif_amplitude' :4 , 'motif_fundamental':4,
                   'sparsity':0.8,'sparsity_fluctuation':0.5,'length_fluctuation':0,'noise_amplitude':0.1}
os.chdir(initial_path+'/../../tsmd')
algorithms=[Grammarviz]

for n_occurences in n_occurences_list:
    generator_params['min_rep']=generator_params['max_rep']=n_occurences
    specific_path=path+'/n_occurences_'+str(n_occurences)+'/'
    if not os.path.exists(specific_path):
        os.makedirs(specific_path)

    exp=Experiment(algorithms)
    exp.run_experiment(specific_path,generator_params)
os.chdir(initial_path)

# %% [markdown]
# ## Scenario 3 : Cardinality Unbalance

# %%
path=initial_path+'/../../data/processed_data/synthetic_data/variable_cardinality/scenario3'
if not os.path.exists(path):
    os.makedirs(path)

# %%
generator_params={'n_motifs':2,'motif_length':100, 'motif_amplitude' :4 , 'motif_fundamental':4,
                   'sparsity':0.8,'sparsity_fluctuation':0.5,'length_fluctuation':0,'noise_amplitude':0.1}

algorithms=[MatrixProfile,PanMatrixProfile,LocoMotif,LatentMotif,MDL,Motiflets,BasePersistentPattern,Valmod,Baseline,AdaptativeBasePersistentPattern]

n_occurences_list=[3,5,10,15,20,30,40,50,100]
for n_occurences1 in n_occurences_list:
    for n_occurences2 in n_occurences_list:
        if n_occurences1<=n_occurences2:
            print(n_occurences1,n_occurences2)
            generator_params['exact_occurences']=[n_occurences1,n_occurences2]
            specific_path=path+'/motifs_occurences_'+str(n_occurences1)+'and'+str(n_occurences2)+'/'
            if not os.path.exists(specific_path):
                os.makedirs(specific_path)

            exp=Experiment(algorithms)
            exp.run_experiment(specific_path,generator_params)

# %%
generator_params={'n_motifs':2,'motif_length':100, 'motif_amplitude' :4 , 'motif_fundamental':4,
                   'sparsity':0.8,'sparsity_fluctuation':0.5,'length_fluctuation':0,'noise_amplitude':0.1}

os.chdir(initial_path+'/../tsmd')
algorithms=[Grammarviz]

n_occurences_list=[3,5,10,15,20,30,40,50,100]
for n_occurences1 in n_occurences_list:
    for n_occurences2 in n_occurences_list:
        if n_occurences1<=n_occurences2:
            print(n_occurences1,n_occurences2)
            generator_params['exact_occurences']=[n_occurences1,n_occurences2]
            specific_path=path+'/motifs_occurences_'+str(n_occurences1)+'and'+str(n_occurences2)+'/'
            if not os.path.exists(specific_path):
                os.makedirs(specific_path)

            exp=Experiment(algorithms)
            exp.run_experiment(specific_path,generator_params)
os.chdir(initial_path)
