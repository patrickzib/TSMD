# %%
import random
random.seed(10)
import os 

initial_path=os.getcwd()
os.chdir(os.getcwd()+'/../..')
from experiments.benchmark_experiment import Experiment

from tsmd.competitors.grammarviz import Grammarviz
from tsmd.competitors.matrixprofile import MatrixProfile
from tsmd.competitors.valmod import Valmod
from tsmd.competitors.mdl import MDL
from tsmd.competitors.locomotif import LocoMotif
from tsmd.competitors.latentmotifs import LatentMotif
from tsmd.competitors.motiflets import Motiflets
from tsmd.competitors.panmatrixprofile import PanMatrixProfile
from tsmd.competitors.persistence import BasePersistentPattern
from tsmd.competitors.setfinder import Baseline
from tsmd.competitors.adaptative_persistence import AdaptativeBasePersistentPattern

os.chdir(initial_path)

# %% [markdown]
# ## Scenario 1 : walk amplitude

# %%
path=initial_path+'/../../data/processed_data/synthetic_data/deformations/scenario1'
if not os.path.exists(path):
    os.makedirs(path)

# %%
algorithms=[MatrixProfile,PanMatrixProfile,LocoMotif,LatentMotif,MDL,Motiflets,BasePersistentPattern,Valmod,Baseline,AdaptativeBasePersistentPattern]
walk_amplitude_list=[0,1,2,3,5,10,15,20,30,50]
generator_params={'n_motifs': 1 ,'motif_length':100, 'motif_amplitude' :4 , 'motif_fundamental':4,
                   'sparsity':0.8,'sparsity_fluctuation':0.5,'min_rep':20,'max_rep':20,'noise_amplitude':0.1,'length_fluctuation':0}

for walk_amplitude in walk_amplitude_list:
    generator_params['walk_amplitude']=walk_amplitude

    specific_path=path+'/walk_amplitude_'+str(walk_amplitude)+'/'
    if not os.path.exists(specific_path):
        os.makedirs(specific_path)

    exp=Experiment(algorithms)
    exp.run_experiment(specific_path,generator_params)
# Out:
# signal_name: repetition_0, algo: MatrixProfile, , f-auc: 0.85, ami: 0.4
# signal_name: repetition_0, algo: PanMatrixProfile, , f-auc: 0.85, ami: 0.4
# signal_name: repetition_0, algo: LocoMotif failed to fit.
# signal_name: repetition_0, algo: LatentMotif failed to fit.
# Iteration 1/50 -- [0.0, -inf, -inf]
# Iteration 2/50 -- [229.421936126296, 0.0, -inf]
# Iteration 3/50 -- [505.25293503036403, 229.421936126296, -19.75536729127103]
# Iteration 4/50 -- [271.22544773348613, 505.25293503036403, 58.11063500029195]
# Iteration 5/50 -- [271.22544773348613, 505.25293503036403, 58.11063500029195]
# Iteration 6/50 -- [271.22544773348613, 505.25293503036403, 58.11063500029195]
# Iteration 7/50 -- [271.22544773348613, 502.0078225325275, 58.11063500029195]
# Iteration 8/50 -- [271.22544773348613, 496.4187339386094, 50.0313214107008]
# Iteration 9/50 -- [271.22544773348613, 493.92850894293633, 50.0313214107008]
# Iteration 10/50 -- [271.22544773348613, 496.80909346417275, 50.0313214107008]
# Iteration 11/50 -- [271.22544773348613, 496.4187339386094, 50.0313214107008]
# Iteration 12/50 -- [271.22544773348613, 496.8090934641726, 50.0313214107008]
# Iteration 13/50 -- [271.22544773348613, 496.80909346417275, 50.0313214107008]
# Iteration 14/50 -- [271.22544773348613, 496.4187339386094, 50.0313214107008]
# Iteration 15/50 -- [271.22544773348613, 493.92850894293633, 50.0313214107008]
# Iteration 16/50 -- [271.22544773348613, 496.05420596200923, 50.0313214107008]
# Iteration 17/50 -- [76.11884030780173, 485.2220147146366, 50.031321410700684]
# Iteration 18/50 -- [76.11884030780173, 489.98946529741823, 50.0313214107008]
# Iteration 19/50 -- [76.11884030780173, 483.98946529741823, 50.031321410700684]
# Iteration 20/50 -- [30.229218908241485, 0.0, 50.031321410700684]
# Iteration 21/50 -- [30.229218908241485, 0.0, -37.98292427653132]

# %%
algorithms=[Grammarviz]
walk_amplitude_list=[0,1,2,3,5,10,15,20,30,50]
generator_params={'n_motifs': 1 ,'motif_length':100, 'motif_amplitude' :4 , 'motif_fundamental':4,
                   'sparsity':0.8,'sparsity_fluctuation':0.5,'min_rep':20,'max_rep':20,'noise_amplitude':0.1,'length_fluctuation':0}
os.chdir(initial_path+'/../../tsmd')
for walk_amplitude in walk_amplitude_list:
    generator_params['walk_amplitude']=walk_amplitude

    specific_path=path+'/walk_amplitude_'+str(walk_amplitude)+'/'
    if not os.path.exists(specific_path):
        os.makedirs(specific_path)

    exp=Experiment(algorithms)
    exp.run_experiment(specific_path,generator_params)
# Out:
# signal_name: repetition_0, algo: Grammarviz, , f-auc: 0.27, ami: 0.01
# signal_name: repetition_1, algo: Grammarviz, , f-auc: 0.08, ami: 0.0
# signal_name: repetition_2, algo: Grammarviz, , f-auc: 0.14, ami: 0.05
# signal_name: repetition_3, algo: Grammarviz, , f-auc: 0.15, ami: -0.0
# signal_name: repetition_4, algo: Grammarviz, , f-auc: 0.34, ami: 0.01
# signal_name: repetition_5, algo: Grammarviz, , f-auc: 0.17, ami: 0.01
# signal_name: repetition_6, algo: Grammarviz failed to fit.
# signal_name: repetition_7, algo: Grammarviz, , f-auc: 0.17, ami: 0.01
# signal_name: repetition_8, algo: Grammarviz, , f-auc: 0.29, ami: 0.02
# signal_name: repetition_9, algo: Grammarviz, , f-auc: 0.29, ami: 0.01
# signal_name: repetition_10, algo: Grammarviz, , f-auc: 0.57, ami: 0.08
# signal_name: repetition_11, algo: Grammarviz, , f-auc: 0.15, ami: 0.01
# signal_name: repetition_12, algo: Grammarviz, , f-auc: 0.61, ami: 0.12
# signal_name: repetition_13, algo: Grammarviz, , f-auc: 0.34, ami: 0.02
# signal_name: repetition_14, algo: Grammarviz, , f-auc: 0.55, ami: 0.06
# signal_name: repetition_15, algo: Grammarviz, , f-auc: 0.42, ami: 0.02
# signal_name: repetition_16, algo: Grammarviz, , f-auc: 0.6, ami: 0.11
# signal_name: repetition_17, algo: Grammarviz, , f-auc: 0.17, ami: 0.01
# signal_name: repetition_18, algo: Grammarviz, , f-auc: 0.09, ami: 0.01
# signal_name: repetition_19, algo: Grammarviz, , f-auc: 0.17, ami: 0.0
# signal_name: repetition_20, algo: Grammarviz, , f-auc: 0.36, ami: 0.01
# signal_name: repetition_21, algo: Grammarviz, , f-auc: 0.14, ami: 0.03
# signal_name: repetition_22, algo: Grammarviz, , f-auc: 0.44, ami: 0.03
# signal_name: repetition_23, algo: Grammarviz, , f-auc: 0.21, ami: 0.01
# signal_name: repetition_24, algo: Grammarviz, , f-auc: 0.6, ami: 0.13
# signal_name: repetition_25, algo: Grammarviz, , f-auc: 0.3, ami: 0.01
# signal_name: repetition_26, algo: Grammarviz, , f-auc: 0.53, ami: 0.04
# signal_name: repetition_27, algo: Grammarviz, , f-auc: 0.39, ami: 0.03
# signal_name: repetition_28, algo: Grammarviz, , f-auc: 0.25, ami: 0.01
# signal_name: repetition_29, algo: Grammarviz, , f-auc: 0.26, ami: 0.01

# %% [markdown]
# ## Scenario 2: Noise amplitude

# %%
path=initial_path+'/../../data/processed_data/synthetic_data/deformations/scenario2'
if not os.path.exists(path):
    os.makedirs(path)

# %%
algorithms=[MatrixProfile,PanMatrixProfile,LocoMotif,LatentMotif,MDL,Motiflets,BasePersistentPattern,Valmod,Baseline,AdaptativeBasePersistentPattern]
noise_amplitude_list=[0.01,0.1,1,3,5,7,10,15,20,50]
generator_params={'n_motifs': 1 ,'motif_length':100, 'motif_amplitude' :4 , 'motif_fundamental':4,
                   'sparsity':0.8,'sparsity_fluctuation':0.5,'min_rep':20,'max_rep':20,'length_fluctuation':0}

for noise_amplitude in noise_amplitude_list:
    generator_params['noise_amplitude']=noise_amplitude

    specific_path=path+'/noise_amplitude_'+str(noise_amplitude)+'/'
    if not os.path.exists(specific_path):
        os.makedirs(specific_path)

    exp=Experiment(algorithms)
    exp.run_experiment(specific_path,generator_params)
# Out:
# signal_name: repetition_0, algo: MatrixProfile, , f-auc: 0.9, ami: 0.55
# signal_name: repetition_0, algo: PanMatrixProfile, , f-auc: 0.9, ami: 0.55
# signal_name: repetition_0, algo: LocoMotif, , f-auc: 0.22, ami: 0.33
# signal_name: repetition_0, algo: LatentMotif, , f-auc: 0.12, ami: 0.01
# Iteration 1/50 -- [0.0, -inf, -inf]
# Iteration 2/50 -- [522.3723505091278, 0.0, -inf]
# Iteration 3/50 -- [221.41859576379548, 522.3723505091278, -200.46301140272112]
# Iteration 4/50 -- [422.24665349005494, 522.3723505091278, -208.54232499231227]
# Iteration 5/50 -- [422.24665349005494, 522.3723505091278, -217.1118635775764]
# Iteration 6/50 -- [422.24665349005494, 522.3723505091278, -225.19117716716755]
# Iteration 7/50 -- [422.24665349005494, 522.3723505091278, -233.2704907567587]
# Iteration 8/50 -- [422.24665349005494, 522.3723505091278, -241.34980434634974]
# Iteration 9/50 -- [422.24665349005494, 522.3723505091278, -248.9388929402678]
# Iteration 10/50 -- [422.24665349005494, 522.3723505091278, -257.01820652985896]
# Iteration 11/50 -- [320.3531131596988, 522.3723505091278, -265.0975201194501]
# Iteration 12/50 -- [283.7999040607969, 522.3723505091278, -273.17683370904115]
# Iteration 13/50 -- [224.92837076812245, 522.3723505091278, -281.2561472986323]
# Iteration 14/50 -- [213.82603278699784, 522.3723505091278, -289.33546088822345]
# Iteration 15/50 -- [213.82603278699784, 522.3723505091278, -297.4147744778145]
# Iteration 16/50 -- [213.82603278699784, 522.3723505091278, -305.49408806740564]
# Iteration 17/50 -- [213.82603278699784, 522.3723505091278, -313.5734016569968]
# Iteration 18/50 -- [131.3479937394909, 522.3723505091278, -321.65271524658795]
# Iteration 19/50 -- [131.3479937394909, 522.3723505091278, -329.732028836179]
# Iteration 20/50 -- [0.0, 521.6174630069644, -337.81134242577014]
# Iteration 21/50 -- [0.0, 0.0, -345.8906560153613]
# Iteration 22/50 -- [0.0, 0.0, 0.0]
# Iteration 23/50 -- [-inf, -inf, 0.0]
# Iteration 24/50 -- [-inf, -inf, 0.0]
# Iteration 25/50 -- [-inf, -inf, -378.69813536939887]
# signal_name: repetition_0, algo: MDL, , f-auc: 1.0, ami: 0.82
# signal_name: repetition_0, algo: Motiflets, , f-auc: 0.17, ami: 0.06
# signal_name: repetition_0, algo: BasePersistentPattern, , f-auc: 0.42, ami: 0.04
# signal_name: repetition_0, algo: Valmod, , f-auc: 0.95, ami: 0.75
# signal_name: repetition_0, algo: ValmodWithoutPruning, , f-auc: 0.9, ami: 0.56
# signal_name: repetition_0, algo: Baseline, , f-auc: 0.52, ami: 0.0
# signal_name: repetition_0, algo: MotifletsNonAdaptative failed to fit.
# signal_name: repetition_0, algo: AdaptativeBasePersistentPattern, , f-auc: 0.57, ami: 0.08
# signal_name: repetition_1, algo: MatrixProfile, , f-auc: 0.77, ami: 0.22
# signal_name: repetition_1, algo: PanMatrixProfile, , f-auc: 0.77, ami: 0.22
# signal_name: repetition_1, algo: LocoMotif, , f-auc: 0.34, ami: 0.07
# signal_name: repetition_1, algo: LatentMotif, , f-auc: 0.29, ami: 0.01
# Iteration 1/50 -- [0.0, -inf, -inf]
# Iteration 2/50 -- [550.2306410590515, 0.0, -inf]
# Iteration 3/50 -- [0.0, 550.2306410590515, -203.70812390055767]
# Iteration 4/50 -- [0.0, 550.2306410590515, -211.7874374901487]
# Iteration 5/50 -- [0.0, 550.2306410590515, -219.37652608406677]
# Iteration 6/50 -- [0.0, 550.2306410590515, -227.45583967365792]
# Iteration 7/50 -- [0.0, 550.2306410590515, -236.02537825892227]
# Iteration 8/50 -- [0.0, 550.2306410590515, -244.1046918485133]
# Iteration 9/50 -- [0.0, 550.2306410590515, -252.18400543810446]
# Iteration 10/50 -- [0.0, 550.2306410590515, -260.2633190276956]
# Iteration 11/50 -- [0.0, 550.2306410590515, -268.34263261728677]
# Iteration 12/50 -- [0.0, 550.2306410590515, -276.4219462068778]
# Iteration 13/50 -- [0.0, 550.2306410590515, -284.50125979646896]
# Iteration 14/50 -- [0.0, 550.2306410590515, -292.5805733860601]
# Iteration 15/50 -- [0.0, 550.2306410590515, -300.65988697565115]
# Iteration 16/50 -- [0.0, 550.2306410590515, -308.7392005652423]
# Iteration 17/50 -- [0.0, 550.2306410590515, -316.81851415483345]
# Iteration 18/50 -- [0.0, 550.2306410590515, -324.8978277444246]
# Iteration 19/50 -- [0.0, 548.2306410590514, -332.97714133401564]
# Iteration 20/50 -- [0.0, 540.1513274694604, -341.0564549236069]
# Iteration 21/50 -- [0.0, 0.0, -347.1211955881979]
# Iteration 22/50 -- [0.0, 0.0, 0.0]
# Iteration 23/50 -- [-inf, 0.0, 0.0]
# Iteration 24/50 -- [-inf, -inf, 0.0]
# Iteration 25/50 -- [-inf, -inf, 0.0]
# Iteration 26/50 -- [-inf, -inf, -389.51776353615344]
# signal_name: repetition_1, algo: MDL, , f-auc: 1.0, ami: 0.81
# signal_name: repetition_1, algo: Motiflets, , f-auc: 0.15, ami: 0.02
# signal_name: repetition_1, algo: BasePersistentPattern, , f-auc: 0.55, ami: 0.06
# signal_name: repetition_1, algo: Valmod, , f-auc: 0.81, ami: 0.3
# signal_name: repetition_1, algo: ValmodWithoutPruning, , f-auc: 0.79, ami: 0.27
# signal_name: repetition_1, algo: Baseline, , f-auc: 0.4, ami: 0.06
# signal_name: repetition_1, algo: MotifletsNonAdaptative failed to fit.
# signal_name: repetition_1, algo: AdaptativeBasePersistentPattern, , f-auc: 0.59, ami: 0.08
# signal_name: repetition_2, algo: MatrixProfile, , f-auc: 0.78, ami: 0.23
# signal_name: repetition_2, algo: PanMatrixProfile, , f-auc: 0.78, ami: 0.23
# signal_name: repetition_2, algo: LocoMotif, , f-auc: 0.42, ami: 0.1
# signal_name: repetition_2, algo: LatentMotif, , f-auc: 0.65, ami: 0.05
# Iteration 1/50 -- [0.0, -inf, -inf]
# Iteration 2/50 -- [537.6174630069642, 0.0, -inf]
# Iteration 3/50 -- [93.95563653739029, 537.6174630069642, -205.81614902371928]
# Iteration 4/50 -- [93.95563653739029, 538.8625755048007, -217.14057511114686]
# Iteration 5/50 -- [332.9432036254818, 530.7832619152097, -221.97477620290158]
# Iteration 6/50 -- [201.77353867706773, 530.7832619152096, -232.62960733327532]
# Iteration 7/50 -- [38.24933618603244, 530.7832619152096, -240.6943479978662]
# Iteration 8/50 -- [230.14254395761532, 530.7832619152096, -247.4141106945109]
# Iteration 9/50 -- [186.4693296881179, 530.7832619152097, -255.47885135910178]
# Iteration 10/50 -- [186.4693296881179, 530.7832619152096, -255.54359202369278]
# Iteration 11/50 -- [54.24384954442555, 530.7832619152096, -261.60833268828367]
# Iteration 12/50 -- [340.0723765282723, 530.7832619152097, -267.67307335287455]
# Iteration 13/50 -- [538.8625755048007, 530.7832619152096, -273.73781401746567]
# Iteration 14/50 -- [125.43095546405661, 538.8625755048007, 512.5021824219984]
# Iteration 15/50 -- [147.87648388432, 538.8625755048007, 504.4228688324073]
# Iteration 16/50 -- [14.144054254182068, 538.8625755048007, 496.34355524281625]
# Iteration 17/50 -- [14.144054254182068, 538.8625755048007, 488.2642416532251]
# Iteration 18/50 -- [14.144054254182068, 538.8625755048007, 480.18492806363395]
# Iteration 19/50 -- [14.144054254182068, 538.8625755048007, 472.1056144740429]
# signal_name: repetition_2, algo: MDL failed to fit.
# signal_name: repetition_2, algo: Motiflets, , f-auc: 0.15, ami: 0.03
# signal_name: repetition_2, algo: BasePersistentPattern, , f-auc: 0.53, ami: 0.07
# signal_name: repetition_2, algo: Valmod, , f-auc: 0.84, ami: 0.36
# signal_name: repetition_2, algo: ValmodWithoutPruning, , f-auc: 0.78, ami: 0.23
# signal_name: repetition_2, algo: Baseline, , f-auc: 0.45, ami: 0.03
# signal_name: repetition_2, algo: MotifletsNonAdaptative failed to fit.
# signal_name: repetition_2, algo: AdaptativeBasePersistentPattern, , f-auc: 0.53, ami: 0.08
# signal_name: repetition_3, algo: MatrixProfile, , f-auc: 0.82, ami: 0.33
# signal_name: repetition_3, algo: PanMatrixProfile, , f-auc: 0.82, ami: 0.33

# %%
algorithms=[Grammarviz]
walk_amplitude_list=[0,1,2,3,5,10,15,20,30,50]
generator_params={'n_motifs': 1 ,'motif_length':100, 'motif_amplitude' :4 , 'motif_fundamental':4,
                   'sparsity':0.8,'sparsity_fluctuation':0.5,'min_rep':20,'max_rep':20,'noise_amplitude':0.1,'length_fluctuation':0}
os.chdir(initial_path+'/../../tsmd')
for walk_amplitude in walk_amplitude_list:
    generator_params['walk_amplitude']=walk_amplitude

    specific_path=path+'/walk_amplitude_'+str(walk_amplitude)+'/'
    if not os.path.exists(specific_path):
        os.makedirs(specific_path)

    exp=Experiment(algorithms)
    exp.run_experiment(specific_path,generator_params)
os.chidr(initial_path)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 9
#       6 for walk_amplitude in walk_amplitude_list:
#       7     generator_params['walk_amplitude']=walk_amplitude
# ----> 9     specific_path=path+'/walk_amplitude_'+str(walk_amplitude)+'/'
#      10     if not os.path.exists(specific_path):
#      11         os.makedirs(specific_path)
#
# NameError: name 'path' is not defined
